# %% [markdown]
# # 📊 DataLens Dashboard — визуализация и анализ ключевых метрик сервиса доставки еды. Аналитическая записка

# %% [markdown]
# ## Бизнес-контекст задачи
#
# Сервис доставки еды «Всё.из.кафе» расширяет клиентскую базу в Саранске и ищет инструмент для регулярного мониторинга показателей. Бизнесу важно понимать, как меняется активность пользователей, сколько клиентов возвращаются за повторными заказами и какова ценность клиента на длинной дистанции. Для этих целей был разработан дашборд с основными метриками.
#
# ## Цель проекта
#
# Проанализировать ключевые метрики клиентской базы сервиса доставки еды «Всё.из.кафе» в Саранске за период с 1 мая по 30 июня 2021 года и на основе этого разработать дашборд с основными показателями, а также подготовить аналитическую записку с выводами для бизнеса.

# %% [markdown]
# ## Результаты анализа ключевых метрик:
#
# 1.	**DAU — ежедневная активность пользователей**
#
# В течение анализируемого периода с 1 мая по 30 июня 2021 года наблюдается `значительный разброс` в показателе ежедневной активности зарегистрированных клиентов по заказам. Минимальное значение DAU составило 17 пользователей (зафиксировано 16 мая), а максимальное — 85 (4 мая), что отражает разброс в 68 единиц. Схожее высокое значение (84) было отмечено также 11 июня.
#
# `Во второй половине июня (с 12.06) наблюдается спад`, что может сигнализировать о проблемах с привлечением пользователей в этот период и требует действий по стабилизации метрики. Также прослеживаются характерные `падения активности в выходные (суббота и воскресенье), а также в праздничные дни` — такие как 9 мая и 12 июня. Это может быть связано с усилением конкуренции со стороны других сервисов или изменением привычек потребителей в нерабочие дни.
#
# В качестве меры по стимулированию спроса можно рассмотреть запуск специальных предложений, акций или бонусных программ, приуроченных к выходным и праздничным датам.
#
# ![DAU](screenshots/DAU.png)

# %% [markdown]
# 2. **Conversion Rate — конверсия из регистрации в размещение заказа.**
#
# Значения показателя конверсии из регистрации в заказ в мае и июне 2021 года варьируются от 18% (18 июня) до 43% (1 мая). В среднем уровень удерживается в диапазоне 26–33%, при этом в течение исследуемого периода `не наблюдается устойчивой восходящей или нисходящей динамики`.
#
# Отдельного внимания заслуживают резкие спады: 28 мая — 19%, 4 июня — 21%, 18 июня — 18%. Все эти даты приходятся на пятницу, и аналогичное снижение показателя в этот день недели прослеживается и в другие недели (за некоторыми исключениями). Это может свидетельствовать о потенциальной закономерности, требующей более детального изучения.
#
# В целом, несмотря на колебания, `показатели конверсии выглядят стабильными`, т.к. для этой метрики характерна высокая вариативность.
#
# ![Conversion Rate](screenshots/Conversion-Rate.png)

# %% [markdown]
# 3. **Средний чек**
#
# `Средний чек` сервиса доставки `в июне составил 147,66 руб.`, что `выше, чем в мае (135,88 руб.)`. Несмотря на рост, делать выводы о формировании устойчивой тенденции пока преждевременно — период наблюдения охватывает всего два месяца. Для более точной оценки динамики стоит продолжать мониторинг показателя в дальнейшем.
#
# Вместе с тем, сравнение среднего чека, количества заказов и DAU по дням показало, что `наиболее высокие, пиковые, значения среднего чека в июне (6, 13 и 19 июня) сопровождались низким количеством заказов и низкой активностью клиентов (DAU)`. Это может говорить о снижении числа новых клиентов в связи с повышением цен, что может быть тревожным сигналом.
#
# При этом можно отметить общее увеличение количества заказов по сравнению с майскими показателями, несмотря на снижение DAU, что может указывать на рост числа повторных заказов и является еще одним аргументов в пользу версии о проблемах с привлечением новых клиентов.

# %% [markdown]
# 4. **Retention Rate**
#
# Коэффициент удержания пользователей (Retention Rate) был проанализирован с двух позиций: `по всей совокупности пользователей` и отдельно `по майской и июньской когортам`. Наиболее резкий спад активности наблюдается уже на следующий день после регистрации: из майской когорты сохраняют активность 14% пользователей, из июньской — 13%. Такое резкое снижение показателя на следующий день после регистрации является нормой, но для более глубокого понимания того, насколько это критично, можно сравнить показатели с рыночными бенчмарками.
#
# `На седьмой день после регистрации Retention Rate снижается до 5% у майской когорты и до 3% у июньско`й. Несмотря на то, что различие между когортами невелико, оно может сигнализировать о снижении способности сервиса удерживать новых пользователей в июне по сравнению с маем. Это может быть связано с сезонным спадом активности пользователей, однако для более точных выводов нужно изучить данные предыдущих лет.
#
# <img src="screenshots/Retention-Rate-1st-week.png" width="700" height="400" alt="Retention Rate">
# <img src="screenshots/Retention-Rate-cohorts.png" width="700" height="400" alt="Retention Rate">

# %% [markdown]
# 5. **LTV ресторанов**
#
# Наибольший суммарный доход в виде комиссии за май и июнь сервис доставки получил от трёх ресторанов: «Гурманское Наслаждение» (170 479 руб.), «Гастрономический Шторм» (164 508 руб.) и «Шоколадный Рай» (61 200 руб.). Можно заметить, что LTV ресторана «Шоколадный Рай» практически в 3 раза меньше, чем LTV «Гастрономического Шторма». Это может говорить как о меньшей популярности кондитерских изделий, так и о разнице в средней стоимости чека или частоте повторных заказов.
#
# Среди заказов из этих заведений были выделены 5 наиболее прибыльных блюд, внёсших наибольший вклад в их LTV. Согласно данным, все эти позиции содержат мясо, а четыре из них — также рыбу. Однако в ряде случаев состав блюд вызывает сомнения: например, наличие одновременно мяса и рыбы в одном блюде представляется маловероятным, а позиция «Брокколи, запечённое в духовке с яйцами и травами» вряд ли действительно содержит мясо или рыбу, как указано в данных. Это может указывать на ошибки в классификации состава блюд.
#
# Кроме того, все эти блюда, по всей видимости, относятся к премиальному сегменту, что объясняет значительный вклад в LTV.

# %% [markdown]
# ## Основные выводы
# Таким образом, были обнаружены следующие тенденции:
# - DAU снижается в праздничные и выходные дни, также наблюдается общий спад активности  во второй половине июня.
# - Показатели Conversion Rate из регистрации в размещение заказа в целом стабильны, но демонстрируют спады по пятницам.
# - Средний чек увеличился в июне по сравнению с маем, но одновременно произошло снижение DAU, что может указывать на сокращение притока новых пользователей из-за повышения цен.
# - Retention Rate у июньской когорты ниже, чем у майской — как на следующий день, так и на 7-й день.
# - Наибольший вклад в LTV ресторанов вносят премиальные блюда.
# - Рестораны, специализирующиеся на кондитерских изделиях, показывают низкий LTV, что может свидетельствовать о меньшей популярности этого сегмента, более низком среднем чеке или редких повторных заказах.
#
# ## Рекомендации:
# - Выяснить причины снижения показателей вовлечённости (DAU, Conversion Rate, Retention Rate) в июне по сравнению с маем: проанализировать маркетинговые кампании, использованные для привлечения пользователей в эти месяцы, а также оценить возможное влияние сезонности, сравнив результаты с аналогичными периодами предыдущих лет.
# - Поскольку активность пользователей снижается в выходные и праздничные дни — разработать специальные акции или предложения, приуроченные к этим дням, чтобы простимулировать спрос.
# - Развивать партнерство с премиальными ресторанами с высокими чеками, т.к. они приносят наибольший LTV.

# %% [markdown]
# ## Результат
#
# ### [Ссылка на дашборд](https://datalens.yandex/e38sblt82vdaz)
#
# ![Дашборд](screenshots/Dashboard-metrics.png)
